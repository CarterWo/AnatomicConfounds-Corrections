# %%
import pandas as pd
import scanpy as sc
from scipy import sparse

# %%
adata_full=sc.read_h5ad(r"C:\Users\woods\OneDrive - University of Missouri\General - Lin Brain Lab - Ogrp\Carter Woods\Vignette_project\H5ADs\napari_updated.h5ad")

# %%
adata_full

# %%
#adata_full=sc.read_h5ad(r"C:\Users\woods\OneDrive - University of Missouri\General - Lin Brain Lab - Ogrp\Carter Woods\Vignette_project\H5ADs\napari_updated.h5ad")


# 2. Load Metadata (Cells)
new_metadata = pd.read_csv(r"C:\Users\woods\OneDrive - University of Missouri\General - Lin Brain Lab - Ogrp\Carter Woods\Vignette_project\seurat_construct\meta_w_quint.csv", index_col=0)

# 4. Add embeddings
new_umap = pd.read_csv(r"C:\Users\woods\OneDrive - University of Missouri\General - Lin Brain Lab - Ogrp\Carter Woods\Vignette_project\seurat_construct\umap.csv", index_col=0)
new_pca = pd.read_csv(r"C:\Users\woods\OneDrive - University of Missouri\General - Lin Brain Lab - Ogrp\Carter Woods\Vignette_project\seurat_construct\umap.csv", index_col=0)


#gemeni, help me attach the new data by the cell names to adata_full. The new metadata can replace the old metadata
adata_full.obs = new_metadata.reindex(adata_full.obs_names)

# 4. Align and Attach Embeddings
# We align the CSVs to the adata cells, then extract .values (numpy array)
adata_full.obsm['X_umap'] = new_umap.reindex(adata_full.obs_names).values
adata_full.obsm['X_pca'] = new_pca.reindex(adata_full.obs_names).values

# 5. Sanity Check
print(f"Metadata shape: {adata_full.obs.shape}")
print(f"UMAP shape: {adata_full.obsm['X_umap'].shape}")
# Out:
# C:\Users\woods\AppData\Local\Temp\ipykernel_11064\3422239360.py:5: DtypeWarning: Columns (6,8,71,94,139,158,184,209,210,212,227,272,273,300,330,331,358,386) have mixed types. Specify dtype option on import or set low_memory=False.
#   new_metadata = pd.read_csv(r"C:\Users\woods\OneDrive - University of Missouri\General - Lin Brain Lab - Ogrp\Carter Woods\Vignette_project\seurat_construct\meta_w_quint.csv", index_col=0)
# Metadata shape: (641383, 399)
# UMAP shape: (641383, 2)

# %%
adata_full.obs['qcCellsPassed'] = adata_full.obs['qcCellsPassed'].astype(str)

# %%
adata_full.write_h5ad(r"C:\Users\woods\OneDrive - University of Missouri\General - Lin Brain Lab - Ogrp\Carter Woods\Vignette_project\H5ADs\quint_updated.h5ad")

# %%
adata_q=sc.read_h5ad(r"C:\Users\woods\OneDrive - University of Missouri\General - Lin Brain Lab - Ogrp\Carter Woods\Vignette_project\H5ADs\quint_updated.h5ad")

# %%
sub=adata_q[adata_q.obs['napari_region']=='Brain_Stem']
sub.obs['sample_ID'].unique()
# Out:
# ['120L', '368R', '1182L']
# Categories (3, object): ['120L', '368R', '1182L']
